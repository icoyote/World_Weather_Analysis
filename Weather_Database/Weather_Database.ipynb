# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
cities

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Date": city_date})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
 

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | harbour breton
# Processing Record 5 of Set 1 | biak
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | espumoso
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | cidreira
# Processing Record 14 of Set 1 | timmins
# Processing Record 15 of Set 1 | san cristobal
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | colac
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | udachnyy
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | parabel
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | ilulissat
# Processing Record 25 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 1 | santa cruz de la palma
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | plon
# Processing Record 30 of Set 1 | carutapera
# Processing Record 31 of Set 1 | teahupoo
# Processing Record 32 of Set 1 | high level
# Processing Record 33 of Set 1 | labrea
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | kavaratti
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | tupelo
# Processing Record 38 of Set 1 | coihaique
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | tete
# Processing Record 43 of Set 1 | dhidhdhoo
# Processing Record 44 of Set 1 | narsaq
# Processing Record 45 of Set 1 | egvekinot
# Processing Record 46 of Set 1 | hamilton
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | broome
# Processing Record 49 of Set 1 | oistins
# Processing Record 50 of Set 1 | alekseyevka
# Processing Record 51 of Set 1 | kahului
# Processing Record 1 of Set 2 | papara
# Processing Record 2 of Set 2 | sechura
# Processing Record 3 of Set 2 | havre-saint-pierre
# Processing Record 4 of Set 2 | kindu
# Processing Record 5 of Set 2 | jasper
# Processing Record 6 of Set 2 | dong hoi
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | dicabisagan
# Processing Record 11 of Set 2 | plettenberg bay
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | hasaki
# Processing Record 14 of Set 2 | ternate
# Processing Record 15 of Set 2 | cherskiy
# Processing Record 16 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | laguna
# Processing Record 20 of Set 2 | port hardy
# Processing Record 21 of Set 2 | jumla
# Processing Record 22 of Set 2 | richards bay
# Processing Record 23 of Set 2 | fukue
# Processing Record 24 of Set 2 | kysyl-syr
# Processing Record 25 of Set 2 | belaya gora
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | dolores
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | rohru
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | andover
# Processing Record 32 of Set 2 | marsaxlokk
# Processing Record 33 of Set 2 | hofn
# Processing Record 34 of Set 2 | pandan
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | quatre cocos
# Processing Record 37 of Set 2 | comodoro rivadavia
# Processing Record 38 of Set 2 | dwarka
# Processing Record 39 of Set 2 | tura
# Processing Record 40 of Set 2 | san andres
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 2 | acapulco
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | ambanja
# Processing Record 46 of Set 2 | waipawa
# Processing Record 47 of Set 2 | beringovskiy
# Processing Record 48 of Set 2 | ciudad bolivar
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | requena
# Processing Record 1 of Set 3 | caravelas
# Processing Record 2 of Set 3 | saint george
# Processing Record 3 of Set 3 | whitianga
# Processing Record 4 of Set 3 | yulara
# Processing Record 5 of Set 3 | dunhua
# Processing Record 6 of Set 3 | endicott
# Processing Record 7 of Set 3 | dingle
# Processing Record 8 of Set 3 | northam
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 3 | sines
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | ucluelet
# Processing Record 14 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | port augusta
# Processing Record 17 of Set 3 | ust-nera
# Processing Record 18 of Set 3 | esperance
# Processing Record 19 of Set 3 | necochea
# Processing Record 20 of Set 3 | merauke
# Processing Record 21 of Set 3 | morondava
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | camacha
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | moron
# Processing Record 26 of Set 3 | airai
# Processing Record 27 of Set 3 | kudahuvadhoo
# Processing Record 28 of Set 3 | sayyan
# Processing Record 29 of Set 3 | narrabri
# Processing Record 30 of Set 3 | joshimath
# Processing Record 31 of Set 3 | marv dasht
# City not found. Skipping...
# Processing Record 32 of Set 3 | zhigansk
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | shaoguan
# Processing Record 35 of Set 3 | valparaiso
# Processing Record 36 of Set 3 | puerto ayacucho
# Processing Record 37 of Set 3 | kamenka
# Processing Record 38 of Set 3 | hithadhoo
# Processing Record 39 of Set 3 | mana
# Processing Record 40 of Set 3 | ahipara
# Processing Record 41 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | thunder bay
# Processing Record 46 of Set 3 | cacule
# Processing Record 47 of Set 3 | jaramana
# City not found. Skipping...
# Processing Record 48 of Set 3 | tautira
# Processing Record 49 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 3 | piacabucu
# Processing Record 1 of Set 4 | khuzhir
# Processing Record 2 of Set 4 | frankenburg
# Processing Record 3 of Set 4 | nuuk
# Processing Record 4 of Set 4 | sungai petani
# Processing Record 5 of Set 4 | nokaneng
# Processing Record 6 of Set 4 | seminole
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | talaya
# Processing Record 9 of Set 4 | fairbanks
# Processing Record 10 of Set 4 | lagoa
# Processing Record 11 of Set 4 | severo-kurilsk
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | haines junction
# Processing Record 15 of Set 4 | leshukonskoye
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | allapalli
# Processing Record 18 of Set 4 | ayagoz
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | tres arroyos
# Processing Record 21 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 4 | eureka
# Processing Record 23 of Set 4 | batemans bay
# Processing Record 24 of Set 4 | new norfolk
# Processing Record 25 of Set 4 | batagay-alyta
# Processing Record 26 of Set 4 | aklavik
# Processing Record 27 of Set 4 | vila velha
# Processing Record 28 of Set 4 | labuan
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | pingyi
# Processing Record 31 of Set 4 | elko
# Processing Record 32 of Set 4 | riviere-au-renard
# Processing Record 33 of Set 4 | palmer
# Processing Record 34 of Set 4 | clyde river
# Processing Record 35 of Set 4 | pangody
# Processing Record 36 of Set 4 | khatanga
# Processing Record 37 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 4 | westport
# Processing Record 39 of Set 4 | lavrentiya
# Processing Record 40 of Set 4 | moose jaw
# Processing Record 41 of Set 4 | husavik
# Processing Record 42 of Set 4 | rocha
# Processing Record 43 of Set 4 | prado
# Processing Record 44 of Set 4 | nikolskoye
# Processing Record 45 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 4 | beloha
# Processing Record 47 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 4 | dharur
# Processing Record 49 of Set 4 | mahebourg
# Processing Record 50 of Set 4 | pangnirtung
# Processing Record 1 of Set 5 | la trinitaria
# Processing Record 2 of Set 5 | talnakh
# Processing Record 3 of Set 5 | mersing
# Processing Record 4 of Set 5 | east london
# Processing Record 5 of Set 5 | komsomolskiy
# Processing Record 6 of Set 5 | berlevag
# Processing Record 7 of Set 5 | juegang
# Processing Record 8 of Set 5 | binabalian
# Processing Record 9 of Set 5 | keetmanshoop
# Processing Record 10 of Set 5 | bonfim
# Processing Record 11 of Set 5 | flinders
# Processing Record 12 of Set 5 | san patricio
# Processing Record 13 of Set 5 | honiara
# Processing Record 14 of Set 5 | cabo san lucas
# Processing Record 15 of Set 5 | kapit
# Processing Record 16 of Set 5 | constitucion
# Processing Record 17 of Set 5 | torbay
# Processing Record 18 of Set 5 | tiksi
# Processing Record 19 of Set 5 | yanaul
# Processing Record 20 of Set 5 | rapid valley
# Processing Record 21 of Set 5 | suez
# Processing Record 22 of Set 5 | mitsamiouli
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | bikaner
# Processing Record 25 of Set 5 | isfana
# Processing Record 26 of Set 5 | pachperwa
# Processing Record 27 of Set 5 | muscat
# Processing Record 28 of Set 5 | caloundra
# Processing Record 29 of Set 5 | mairana
# Processing Record 30 of Set 5 | mount gambier
# Processing Record 31 of Set 5 | urumqi
# Processing Record 32 of Set 5 | shihezi
# Processing Record 33 of Set 5 | chambersburg
# Processing Record 34 of Set 5 | prince albert
# Processing Record 35 of Set 5 | kununurra
# Processing Record 36 of Set 5 | lexington
# Processing Record 37 of Set 5 | bethel
# Processing Record 38 of Set 5 | altyn-topkan
# Processing Record 39 of Set 5 | tuktoyaktuk
# Processing Record 40 of Set 5 | pouembout
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 45 of Set 5 | manokwari
# Processing Record 46 of Set 5 | port macquarie
# Processing Record 47 of Set 5 | marau
# Processing Record 48 of Set 5 | businga
# Processing Record 49 of Set 5 | puro
# Processing Record 50 of Set 5 | pitimbu
# Processing Record 1 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 2 of Set 6 | kailua
# Processing Record 3 of Set 6 | hualmay
# Processing Record 4 of Set 6 | tyumentsevo
# Processing Record 5 of Set 6 | naron
# Processing Record 6 of Set 6 | lagunas
# Processing Record 7 of Set 6 | soyo
# Processing Record 8 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 10 of Set 6 | sisimiut
# Processing Record 11 of Set 6 | sao joao do piaui
# Processing Record 12 of Set 6 | la ronge
# Processing Record 13 of Set 6 | viransehir
# Processing Record 14 of Set 6 | grindavik
# Processing Record 15 of Set 6 | bambous virieux
# Processing Record 16 of Set 6 | guerrero negro
# Processing Record 17 of Set 6 | bandarbeyla
# Processing Record 18 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 6 | bellavista
# Processing Record 20 of Set 6 | araguari
# Processing Record 21 of Set 6 | rawson
# Processing Record 22 of Set 6 | tessalit
# Processing Record 23 of Set 6 | watertown
# Processing Record 24 of Set 6 | vardo
# Processing Record 25 of Set 6 | sao joao da barra
# Processing Record 26 of Set 6 | umm lajj
# Processing Record 27 of Set 6 | lethem
# Processing Record 28 of Set 6 | nouadhibou
# Processing Record 29 of Set 6 | mount isa
# Processing Record 30 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 31 of Set 6 | menomonie
# Processing Record 32 of Set 6 | los llanos de aridane
# Processing Record 33 of Set 6 | wajima
# Processing Record 34 of Set 6 | chengde
# Processing Record 35 of Set 6 | birao
# Processing Record 36 of Set 6 | lovozero
# Processing Record 37 of Set 6 | nome
# Processing Record 38 of Set 6 | asosa
# Processing Record 39 of Set 6 | vidim
# Processing Record 40 of Set 6 | korla
# Processing Record 41 of Set 6 | kutum
# Processing Record 42 of Set 6 | qandala
# Processing Record 43 of Set 6 | kupang
# Processing Record 44 of Set 6 | hervey bay
# Processing Record 45 of Set 6 | ladan
# Processing Record 46 of Set 6 | hambantota
# Processing Record 47 of Set 6 | saskylakh
# Processing Record 48 of Set 6 | petropavlovka
# Processing Record 49 of Set 6 | chokurdakh
# Processing Record 50 of Set 6 | longyearbyen
# Processing Record 1 of Set 7 | porto novo
# Processing Record 2 of Set 7 | broken hill
# Processing Record 3 of Set 7 | susanville
# Processing Record 4 of Set 7 | riyadh
# Processing Record 5 of Set 7 | shitanjing
# Processing Record 6 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 7 | aksarka
# Processing Record 8 of Set 7 | guiratinga
# Processing Record 9 of Set 7 | dalby
# Processing Record 10 of Set 7 | sungaipenuh
# Processing Record 11 of Set 7 | shelburne
# Processing Record 12 of Set 7 | emmett
# Processing Record 13 of Set 7 | uray
# Processing Record 14 of Set 7 | maceio
# Processing Record 15 of Set 7 | wanning
# Processing Record 16 of Set 7 | tutoia
# Processing Record 17 of Set 7 | mwinilunga
# Processing Record 18 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 7 | aquiraz
# Processing Record 20 of Set 7 | roald
# Processing Record 21 of Set 7 | sao filipe
# Processing Record 22 of Set 7 | ranong
# Processing Record 23 of Set 7 | asau
# Processing Record 24 of Set 7 | muscle shoals
# Processing Record 25 of Set 7 | castro
# Processing Record 26 of Set 7 | itumbiara
# Processing Record 27 of Set 7 | keita
# Processing Record 28 of Set 7 | provideniya
# Processing Record 29 of Set 7 | koster
# Processing Record 30 of Set 7 | seoul
# Processing Record 31 of Set 7 | qui nhon
# Processing Record 32 of Set 7 | bulancak
# Processing Record 33 of Set 7 | kruisfontein
# Processing Record 34 of Set 7 | makubetsu
# Processing Record 35 of Set 7 | ankazobe
# Processing Record 36 of Set 7 | alur
# Processing Record 37 of Set 7 | neuquen
# Processing Record 38 of Set 7 | prieska
# Processing Record 39 of Set 7 | bucerias
# Processing Record 40 of Set 7 | glazov
# Processing Record 41 of Set 7 | ucar
# Processing Record 42 of Set 7 | te anau
# Processing Record 43 of Set 7 | asyut
# Processing Record 44 of Set 7 | bairiki
# Processing Record 45 of Set 7 | minot
# Processing Record 46 of Set 7 | springbok
# Processing Record 47 of Set 7 | nisia floresta
# Processing Record 48 of Set 7 | mandera
# Processing Record 49 of Set 7 | dikson
# Processing Record 50 of Set 7 | bubaque
# Processing Record 1 of Set 8 | klaksvik
# Processing Record 2 of Set 8 | naila
# Processing Record 3 of Set 8 | kumluca
# Processing Record 4 of Set 8 | portland
# Processing Record 5 of Set 8 | bilibino
# Processing Record 6 of Set 8 | vryburg
# Processing Record 7 of Set 8 | sorland
# Processing Record 8 of Set 8 | hauzenberg
# Processing Record 9 of Set 8 | octeville
# Processing Record 10 of Set 8 | salalah
# Processing Record 11 of Set 8 | kitami
# Processing Record 12 of Set 8 | ponta do sol
# Processing Record 13 of Set 8 | atar
# Processing Record 14 of Set 8 | arlit
# Processing Record 15 of Set 8 | ancud
# Processing Record 16 of Set 8 | jiangyou
# Processing Record 17 of Set 8 | nurota
# Processing Record 18 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 19 of Set 8 | paita
# Processing Record 20 of Set 8 | puerto varas
# Processing Record 21 of Set 8 | si racha
# Processing Record 22 of Set 8 | mangrol
# Processing Record 23 of Set 8 | saint-pierre
# Processing Record 24 of Set 8 | kucevo
# Processing Record 25 of Set 8 | pisco
# Processing Record 26 of Set 8 | porto de moz
# Processing Record 27 of Set 8 | oranjemund
# Processing Record 28 of Set 8 | mackenzie
# Processing Record 29 of Set 8 | kaka
# Processing Record 30 of Set 8 | benghazi
# Processing Record 31 of Set 8 | eyl
# Processing Record 32 of Set 8 | balkanabat
# Processing Record 33 of Set 8 | port blair
# Processing Record 34 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 8 | flin flon
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | grand-bourg
# Processing Record 38 of Set 8 | calahorra
# Processing Record 39 of Set 8 | anyang
# Processing Record 40 of Set 8 | ayan
# Processing Record 41 of Set 8 | saint anthony
# Processing Record 42 of Set 8 | rio hato
# Processing Record 43 of Set 8 | vestmanna
# Processing Record 44 of Set 8 | shache
# Processing Record 45 of Set 8 | yar-sale
# Processing Record 46 of Set 8 | harper
# Processing Record 47 of Set 8 | asfi
# Processing Record 48 of Set 8 | cap malheureux
# Processing Record 49 of Set 8 | burley
# Processing Record 50 of Set 8 | flagstaff
# Processing Record 1 of Set 9 | myitkyina
# Processing Record 2 of Set 9 | dharchula
# Processing Record 3 of Set 9 | saint-philippe
# Processing Record 4 of Set 9 | ostrovnoy
# Processing Record 5 of Set 9 | inhambane
# Processing Record 6 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 9 | vanimo
# Processing Record 8 of Set 9 | zverinogolovskoye
# Processing Record 9 of Set 9 | mackay
# Processing Record 10 of Set 9 | nemuro
# Processing Record 11 of Set 9 | metu
# Processing Record 12 of Set 9 | kabinda
# Processing Record 13 of Set 9 | alekseyevsk
# Processing Record 14 of Set 9 | namatanai
# Processing Record 15 of Set 9 | kaeo
# Processing Record 16 of Set 9 | bac lieu
# Processing Record 17 of Set 9 | chapais
# Processing Record 18 of Set 9 | goderich
# Processing Record 19 of Set 9 | praia da vitoria
# Processing Record 20 of Set 9 | the valley
# Processing Record 21 of Set 9 | matagami
# Processing Record 22 of Set 9 | bolshiye uki
# City not found. Skipping...
# Processing Record 23 of Set 9 | manadhoo
# Processing Record 24 of Set 9 | luangwa
# Processing Record 25 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 26 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 27 of Set 9 | acarau
# Processing Record 28 of Set 9 | ronda
# Processing Record 29 of Set 9 | tuatapere
# Processing Record 30 of Set 9 | baiquan
# Processing Record 31 of Set 9 | itarema
# Processing Record 32 of Set 9 | havelock
# Processing Record 33 of Set 9 | marawi
# Processing Record 34 of Set 9 | liniere
# City not found. Skipping...
# Processing Record 35 of Set 9 | cooma
# Processing Record 36 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 9 | jaque
# Processing Record 39 of Set 9 | grand gaube
# Processing Record 40 of Set 9 | half moon bay
# Processing Record 41 of Set 9 | luwuk
# Processing Record 42 of Set 9 | dunedin
# Processing Record 43 of Set 9 | emerald
# Processing Record 44 of Set 9 | gondar
# Processing Record 45 of Set 9 | padre paraiso
# Processing Record 46 of Set 9 | sangar
# Processing Record 47 of Set 9 | kelvington
# Processing Record 48 of Set 9 | dulce nombre de culmi
# Processing Record 49 of Set 9 | sistranda
# Processing Record 50 of Set 9 | basco
# Processing Record 1 of Set 10 | rio cuarto
# Processing Record 2 of Set 10 | katangli
# Processing Record 3 of Set 10 | hermiston
# Processing Record 4 of Set 10 | shambu
# Processing Record 5 of Set 10 | berbera
# Processing Record 6 of Set 10 | sydney
# Processing Record 7 of Set 10 | sao jose da coroa grande
# Processing Record 8 of Set 10 | khor
# Processing Record 9 of Set 10 | peleduy
# Processing Record 10 of Set 10 | dubbo
# Processing Record 11 of Set 10 | jawhar
# Processing Record 12 of Set 10 | saharsa
# Processing Record 13 of Set 10 | tishchenskoye
# Processing Record 14 of Set 10 | mahon
# Processing Record 15 of Set 10 | sverdlovskiy
# Processing Record 16 of Set 10 | slave lake
# Processing Record 17 of Set 10 | lorengau
# Processing Record 18 of Set 10 | bengkulu
# Processing Record 19 of Set 10 | jalu
# Processing Record 20 of Set 10 | dawlatabad
# Processing Record 21 of Set 10 | iqaluit
# Processing Record 22 of Set 10 | latung
# Processing Record 23 of Set 10 | zhanaozen
# Processing Record 24 of Set 10 | banda aceh
# Processing Record 25 of Set 10 | sona
# Processing Record 26 of Set 10 | show low
# Processing Record 27 of Set 10 | champerico
# Processing Record 28 of Set 10 | dujuma
# City not found. Skipping...
# Processing Record 29 of Set 10 | karacakoy
# Processing Record 30 of Set 10 | yarkovo
# Processing Record 31 of Set 10 | butembo
# Processing Record 32 of Set 10 | campoverde
# Processing Record 33 of Set 10 | ewa beach
# Processing Record 34 of Set 10 | krasnoselkup
# Processing Record 35 of Set 10 | quelimane
# Processing Record 36 of Set 10 | kedrovyy
# Processing Record 37 of Set 10 | nioro
# Processing Record 38 of Set 10 | wilmington
# Processing Record 39 of Set 10 | tarko-sale
# Processing Record 40 of Set 10 | raudeberg
# Processing Record 41 of Set 10 | koutiala
# Processing Record 42 of Set 10 | terney
# Processing Record 43 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 44 of Set 10 | nalbari
# Processing Record 45 of Set 10 | cururupu
# Processing Record 46 of Set 10 | adrar
# Processing Record 47 of Set 10 | kabompo
# Processing Record 48 of Set 10 | nayoro
# Processing Record 49 of Set 10 | atka
# City not found. Skipping...
# Processing Record 50 of Set 10 | waldoboro
# Processing Record 1 of Set 11 | margate
# Processing Record 2 of Set 11 | barcelona
# Processing Record 3 of Set 11 | canto do buriti
# Processing Record 4 of Set 11 | tobol
# Processing Record 5 of Set 11 | amapa
# Processing Record 6 of Set 11 | monrovia
# Processing Record 7 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 11 | deputatskiy
# Processing Record 9 of Set 11 | zhangye
# Processing Record 10 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 11 | montorio al vomano
# Processing Record 12 of Set 11 | baykit
# Processing Record 13 of Set 11 | gornyye klyuchi
# Processing Record 14 of Set 11 | venice
# Processing Record 15 of Set 11 | ratnagiri
# Processing Record 16 of Set 11 | preobrazheniye
# Processing Record 17 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 18 of Set 11 | siderno
# Processing Record 19 of Set 11 | kajaani
# Processing Record 20 of Set 11 | beyneu
# Processing Record 21 of Set 11 | marfino
# Processing Record 22 of Set 11 | kabanjahe
# Processing Record 23 of Set 11 | a
# City not found. Skipping...
# Processing Record 24 of Set 11 | athens
# Processing Record 25 of Set 11 | rio gallegos
# Processing Record 26 of Set 11 | tibagi
# Processing Record 27 of Set 11 | xianyang
# Processing Record 28 of Set 11 | nizhneangarsk
# Processing Record 29 of Set 11 | oksfjord
# Processing Record 30 of Set 11 | faya
# Processing Record 31 of Set 11 | codrington
# Processing Record 32 of Set 11 | turiacu
# Processing Record 33 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 11 | carlsbad
# Processing Record 35 of Set 11 | fortuna
# Processing Record 36 of Set 11 | najran
# Processing Record 37 of Set 11 | seryshevo
# Processing Record 38 of Set 11 | veraval
# Processing Record 39 of Set 11 | visnes
# Processing Record 40 of Set 11 | tucurui
# Processing Record 41 of Set 11 | yishui
# Processing Record 42 of Set 11 | usinsk
# Processing Record 43 of Set 11 | jalgaon
# Processing Record 44 of Set 11 | haigerloch
# Processing Record 45 of Set 11 | neka
# Processing Record 46 of Set 11 | sur
# Processing Record 47 of Set 11 | apache junction
# Processing Record 48 of Set 11 | ilo
# Processing Record 49 of Set 11 | mon
# Processing Record 50 of Set 11 | sault sainte marie
# Processing Record 1 of Set 12 | xifeng
# Processing Record 2 of Set 12 | catuday
# Processing Record 3 of Set 12 | russell
# Processing Record 4 of Set 12 | lira
# Processing Record 5 of Set 12 | ginda
# Processing Record 6 of Set 12 | grand-santi
# Processing Record 7 of Set 12 | zeya
# Processing Record 8 of Set 12 | buala
# Processing Record 9 of Set 12 | gimli
# Processing Record 10 of Set 12 | mao
# Processing Record 11 of Set 12 | novyy urengoy
# Processing Record 12 of Set 12 | pamanukan
# Processing Record 13 of Set 12 | kyabe
# Processing Record 14 of Set 12 | shugurovo
# Processing Record 15 of Set 12 | christchurch
# Processing Record 16 of Set 12 | tongzi
# Processing Record 17 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 12 | antalaha
# Processing Record 19 of Set 12 | salym
# Processing Record 20 of Set 12 | katsuura
# Processing Record 21 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 22 of Set 12 | mayo
# Processing Record 23 of Set 12 | birjand
# Processing Record 24 of Set 12 | ruse
# Processing Record 25 of Set 12 | indian head
# Processing Record 26 of Set 12 | minggang
# Processing Record 27 of Set 12 | taltal
# Processing Record 28 of Set 12 | great yarmouth
# Processing Record 29 of Set 12 | tyukalinsk
# Processing Record 30 of Set 12 | vila
# Processing Record 31 of Set 12 | dunmore town
# Processing Record 32 of Set 12 | stepnyak
# Processing Record 33 of Set 12 | malaya purga
# Processing Record 34 of Set 12 | port shepstone
# Processing Record 35 of Set 12 | guicheng
# City not found. Skipping...
# Processing Record 36 of Set 12 | palma del rio
# Processing Record 37 of Set 12 | jhajjar
# Processing Record 38 of Set 12 | kosh-agach
# Processing Record 39 of Set 12 | la orilla
# Processing Record 40 of Set 12 | bathsheba
# Processing Record 41 of Set 12 | ronne
# Processing Record 42 of Set 12 | saint-augustin
# Processing Record 43 of Set 12 | filingue
# Processing Record 44 of Set 12 | le moule
# Processing Record 45 of Set 12 | viedma
# Processing Record 46 of Set 12 | jarocin
# Processing Record 47 of Set 12 | leh
# Processing Record 48 of Set 12 | kassala
# Processing Record 49 of Set 12 | jambi
# Processing Record 50 of Set 12 | sobolevo
# Processing Record 1 of Set 13 | excelsior springs
# Processing Record 2 of Set 13 | komatipoort
# Processing Record 3 of Set 13 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 4 of Set 13 | kalmunai
# Processing Record 5 of Set 13 | galbshtadt
# Processing Record 6 of Set 13 | bystryy istok
# Processing Record 7 of Set 13 | port-cartier
# Processing Record 8 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 13 | sao paulo de olivenca
# Processing Record 10 of Set 13 | huarmey
# Processing Record 11 of Set 13 | sumbe
# Processing Record 12 of Set 13 | glendive
# Processing Record 13 of Set 13 | labuhan
# Processing Record 14 of Set 13 | pochutla
# Processing Record 15 of Set 13 | alamosa
# Processing Record 16 of Set 13 | plymouth
# Processing Record 17 of Set 13 | acajutla
# Processing Record 18 of Set 13 | pangkalanbuun
# Processing Record 19 of Set 13 | alice springs
# Processing Record 20 of Set 13 | yurkivka
# Processing Record 21 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 13 | pontianak
# Processing Record 23 of Set 13 | ixtapa
# Processing Record 24 of Set 13 | dingzhou
# Processing Record 25 of Set 13 | mancio lima
# Processing Record 26 of Set 13 | dedza
# Processing Record 27 of Set 13 | saint-francois
# Processing Record 28 of Set 13 | mahanoro
# Processing Record 29 of Set 13 | noyabrsk
# Processing Record 30 of Set 13 | aksay
# Processing Record 31 of Set 13 | netrakona
# Processing Record 32 of Set 13 | puerto escondido
# Processing Record 33 of Set 13 | duvan
# Processing Record 34 of Set 13 | jasdan
# Processing Record 35 of Set 13 | synya
# Processing Record 36 of Set 13 | san quintin
# Processing Record 37 of Set 13 | visconde do rio branco
# Processing Record 38 of Set 13 | nanyang
# Processing Record 39 of Set 13 | luang prabang
# Processing Record 40 of Set 13 | tefe
# Processing Record 41 of Set 13 | burica
# City not found. Skipping...
# Processing Record 42 of Set 13 | turmalina
# Processing Record 43 of Set 13 | okhotsk
# Processing Record 44 of Set 13 | sioux lookout
# Processing Record 45 of Set 13 | kamiiso
# Processing Record 46 of Set 13 | olafsvik
# Processing Record 47 of Set 13 | kharp
# Processing Record 48 of Set 13 | dan khun thot
# Processing Record 49 of Set 13 | olutanga
# Processing Record 50 of Set 13 | siguiri
# Processing Record 1 of Set 14 | sinjar
# Processing Record 2 of Set 14 | taywarah
# Processing Record 3 of Set 14 | bilma
# Processing Record 4 of Set 14 | lindas
# Processing Record 5 of Set 14 | edd
# Processing Record 6 of Set 14 | tambura
# Processing Record 7 of Set 14 | yeppoon
# Processing Record 8 of Set 14 | oxford
# Processing Record 9 of Set 14 | epe
# Processing Record 10 of Set 14 | port moresby
# Processing Record 11 of Set 14 | la cruz
# Processing Record 12 of Set 14 | bereda
# Processing Record 13 of Set 14 | aykhal
# Processing Record 14 of Set 14 | barra
# Processing Record 15 of Set 14 | bitung
# Processing Record 16 of Set 14 | gamba
# Processing Record 17 of Set 14 | belaya glina
# Processing Record 18 of Set 14 | talcahuano
# Processing Record 19 of Set 14 | atagay
# Processing Record 20 of Set 14 | taoudenni
# Processing Record 21 of Set 14 | bud
# Processing Record 22 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 14 | nekhayevskiy
# Processing Record 24 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 14 | yenagoa
# Processing Record 26 of Set 14 | singapore
# Processing Record 27 of Set 14 | boca do acre
# Processing Record 28 of Set 14 | alugan
# Processing Record 29 of Set 14 | coquimbo
# Processing Record 30 of Set 14 | dudinka
# Processing Record 31 of Set 14 | beatrice
# Processing Record 32 of Set 14 | pevek
# Processing Record 33 of Set 14 | warwick
# Processing Record 34 of Set 14 | mecca
# Processing Record 35 of Set 14 | dosso
# Processing Record 36 of Set 14 | mudgee
# Processing Record 37 of Set 14 | maxixe
# Processing Record 38 of Set 14 | villaviciosa
# Processing Record 39 of Set 14 | barrhead
# Processing Record 40 of Set 14 | akyab
# Processing Record 41 of Set 14 | honningsvag
# Processing Record 42 of Set 14 | pouebo
# Processing Record 43 of Set 14 | tromso
# Processing Record 44 of Set 14 | gladstone
# Processing Record 45 of Set 14 | ilebo
# Processing Record 46 of Set 14 | prince rupert
# Processing Record 47 of Set 14 | xucheng
# Processing Record 48 of Set 14 | nalut
# Processing Record 49 of Set 14 | menongue
# Processing Record 50 of Set 14 | okotoks
# Processing Record 1 of Set 15 | thilogne
# City not found. Skipping...
# Processing Record 2 of Set 15 | twentynine palms
# Processing Record 3 of Set 15 | pueblo
# Processing Record 4 of Set 15 | ferme-neuve
# Processing Record 5 of Set 15 | karaman
# Processing Record 6 of Set 15 | zorritos
# Processing Record 7 of Set 15 | luanshya
# Processing Record 8 of Set 15 | creel
# Processing Record 9 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 10 of Set 15 | ulaangom
# Processing Record 11 of Set 15 | grand baie
# Processing Record 12 of Set 15 | belyy yar
# Processing Record 13 of Set 15 | rodino
# Processing Record 14 of Set 15 | mirnyy
# Processing Record 15 of Set 15 | nhulunbuy
# Processing Record 16 of Set 15 | palembang
# Processing Record 17 of Set 15 | tocopilla
# Processing Record 18 of Set 15 | umba
# Processing Record 19 of Set 15 | osorno
# Processing Record 20 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 15 | mildura
# Processing Record 22 of Set 15 | taraz
# Processing Record 23 of Set 15 | paamiut
# Processing Record 24 of Set 15 | touros
# Processing Record 25 of Set 15 | zhangjiakou
# Processing Record 26 of Set 15 | kizilskoye
# Processing Record 27 of Set 15 | abnub
# Processing Record 28 of Set 15 | porto santo
# Processing Record 29 of Set 15 | sinnamary
# Processing Record 30 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 15 | jardim
# Processing Record 32 of Set 15 | yerbogachen
# Processing Record 33 of Set 15 | khani
# Processing Record 34 of Set 15 | umea
# Processing Record 35 of Set 15 | la seyne-sur-mer
# Processing Record 36 of Set 15 | acevedo
# Processing Record 37 of Set 15 | villa carlos paz
# Processing Record 38 of Set 15 | dustlik
# Processing Record 39 of Set 15 | abonnema
# Processing Record 40 of Set 15 | namwala
# Processing Record 41 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 42 of Set 15 | nacala
# Processing Record 43 of Set 15 | kalianget
# Processing Record 44 of Set 15 | ibra
# Processing Record 45 of Set 15 | sulangan
# Processing Record 46 of Set 15 | modasa
# Processing Record 47 of Set 15 | omsukchan
# Processing Record 48 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 15 | peniche
# Processing Record 50 of Set 15 | naryan-mar
# Processing Record 1 of Set 16 | karratha
# Processing Record 2 of Set 16 | vilhena
# Processing Record 3 of Set 16 | harer
# Processing Record 4 of Set 16 | hobyo
# Processing Record 5 of Set 16 | kloulklubed
# Processing Record 6 of Set 16 | giyon
# Processing Record 7 of Set 16 | cabedelo
# Processing Record 8 of Set 16 | pavilosta
# Processing Record 9 of Set 16 | togur
# Processing Record 10 of Set 16 | ouallam
# Processing Record 11 of Set 16 | sarankhola
# Processing Record 12 of Set 16 | wenceslau braz
# Processing Record 13 of Set 16 | zolotinka
# City not found. Skipping...
# Processing Record 14 of Set 16 | praia
# Processing Record 15 of Set 16 | manturovo
# Processing Record 16 of Set 16 | sehithwa
# Processing Record 17 of Set 16 | maine-soroa
# Processing Record 18 of Set 16 | awbari
# Processing Record 19 of Set 16 | xai-xai
# Processing Record 20 of Set 16 | miandrivazo
# Processing Record 21 of Set 16 | cameta
# Processing Record 22 of Set 16 | oktyabrskoye
# Processing Record 23 of Set 16 | nanortalik
# Processing Record 24 of Set 16 | san carlos del zulia
# Processing Record 25 of Set 16 | chapada dos guimaraes
# Processing Record 26 of Set 16 | maroantsetra
# Processing Record 27 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 28 of Set 16 | tamiahua
# Processing Record 29 of Set 16 | barranca
# Processing Record 30 of Set 16 | daxian
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.6500  115.3333     14.50        91          18
# 1  Harbour Breton      CA  47.4833  -55.7983      3.87        75          70
# 2            Biak      ID  -0.9131  122.8766     24.92        83          95
# 3        Luderitz      NA -26.6481   15.1594     15.94        67           0
# 4      Kaitangata      NZ -46.2817  169.8464     15.13        57          82
# 5         Mataura      NZ -46.1927  168.8643     11.38        79          93
# 6           Vaini      TO -21.2000 -175.2000     25.09        94          20
# 7        Espumoso      BR -28.7247  -52.8497     19.66        51           0
# 8           Kapaa      US  22.0752 -159.3190     23.99        83          40
# 9       Cape Town      ZA -33.9258   18.4232     16.86        61          17
#
#    Wind Speed Current Description                 Date
# 0        3.00          few clouds  2022-04-15 18:08:19
# 1        2.28       broken clouds  2022-04-15 18:08:19
# 2        0.86       moderate rain  2022-04-15 18:08:20
# 3       11.56           clear sky  2022-04-15 18:08:20
# 4        6.10       broken clouds  2022-04-15 18:08:21
# 5        5.31          light rain  2022-04-15 18:05:15
# 6        1.54          few clouds  2022-04-15 18:08:21
# 7        3.09           clear sky  2022-04-15 18:08:21
# 8        6.69    scattered clouds  2022-04-15 18:08:22
# 9        4.92          few clouds  2022-04-15 18:04:31

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp",
                    "Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0       Busselton      AU  2022-04-15 18:08:19 -33.6500  115.3333     14.50
# 1  Harbour Breton      CA  2022-04-15 18:08:19  47.4833  -55.7983      3.87
# 2            Biak      ID  2022-04-15 18:08:20  -0.9131  122.8766     24.92
# 3        Luderitz      NA  2022-04-15 18:08:20 -26.6481   15.1594     15.94
# 4      Kaitangata      NZ  2022-04-15 18:08:21 -46.2817  169.8464     15.13
# 5         Mataura      NZ  2022-04-15 18:05:15 -46.1927  168.8643     11.38
# 6           Vaini      TO  2022-04-15 18:08:21 -21.2000 -175.2000     25.09
# 7        Espumoso      BR  2022-04-15 18:08:21 -28.7247  -52.8497     19.66
# 8           Kapaa      US  2022-04-15 18:08:22  22.0752 -159.3190     23.99
# 9       Cape Town      ZA  2022-04-15 18:04:31 -33.9258   18.4232     16.86
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        91          18        3.00          few clouds
# 1        75          70        2.28       broken clouds
# 2        83          95        0.86       moderate rain
# 3        67           0       11.56           clear sky
# 4        57          82        6.10       broken clouds
# 5        79          93        5.31          light rain
# 6        94          20        1.54          few clouds
# 7        51           0        3.09           clear sky
# 8        83          40        6.69    scattered clouds
# 9        61          17        4.92          few clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
